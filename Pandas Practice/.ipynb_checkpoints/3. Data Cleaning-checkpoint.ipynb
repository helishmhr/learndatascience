# %% [markdown]
# # **Data Cleaning**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Handling Missing values**

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [np.nan, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, 5],
    'D': [1, 2, 3, 4, 5]
}
df = pd.DataFrame(data)
print(df)
# Out:
#      A    B    C  D
# 0  1.0  NaN  1.0  1
# 1  2.0  2.0  2.0  2
# 2  NaN  3.0  3.0  3
# 3  4.0  4.0  NaN  4
# 4  5.0  5.0  5.0  5

# %%
#checking missing values
print(df.isna())
# Out:
#        A      B      C      D
# 0  False   True  False  False
# 1  False  False  False  False
# 2   True  False  False  False
# 3  False  False   True  False
# 4  False  False  False  False

# %%
#Removing rows that contain at least one missing value
print(df.dropna())
# Out:
#      A    B    C  D
# 1  2.0  2.0  2.0  2
# 4  5.0  5.0  5.0  5

# %%
#filling missing values with 0
print(df.fillna(0))
# Out:
#      A    B    C  D
# 0  1.0  0.0  1.0  1
# 1  2.0  2.0  2.0  2
# 2  0.0  3.0  3.0  3
# 3  4.0  4.0  0.0  4
# 4  5.0  5.0  5.0  5

# %%
#Filling missing values Only For Specified Columns
print(df.fillna({'A':200,'C': 100}))
# Out:
#        A    B      C  D
# 0    1.0  NaN    1.0  1
# 1    2.0  2.0    2.0  2
# 2  200.0  3.0    3.0  3
# 3    4.0  4.0  100.0  4
# 4    5.0  5.0    5.0  5

# %%
#filling with mean
x = df["C"].mean()
df.fillna({"C": x})
# Out:
#      A    B     C  D
# 0  1.0  NaN  1.00  1
# 1  2.0  2.0  2.00  2
# 2  NaN  3.0  3.00  3
# 3  4.0  4.0  2.75  4
# 4  5.0  5.0  5.00  5

# %% [markdown]
# **Note:**\
# By default,all these method returns a new DataFrame, and will not change the original.\
# If you want to change the original DataFrame, use the *inplace = True* argument

# %% [markdown]
# ## **Changing Data type**

# %%
data = {'Name': ['John', 'Alice', 'Bob', 'Eve', 'Charlie'], 
        'Age': [25, 30, 22, 35, 28], 
        'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'], 
        'Salary': [50000, 55000, 40000, 70000, 48000],
       'Join Date':['2021-01-01', '2020-05-22', '2022-03-15', '2021-07-30', '2020-11-11'] }
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Gender  Salary   Join Date
# 0     John   25    Male   50000  2021-01-01
# 1    Alice   30  Female   55000  2020-05-22
# 2      Bob   22    Male   40000  2022-03-15
# 3      Eve   35  Female   70000  2021-07-30
# 4  Charlie   28    Male   48000  2020-11-11

# %%
#viewing data types of each column
print(df.dtypes)
# Out:
# Name         object
# Age           int64
# Gender       object
# Salary        int64
# Join Date    object
# dtype: object

# %%
# Convert 'Age' column to float type
df['Age'] = df['Age'].astype(float)
print(df.dtypes)
# Out:
# Name          object
# Age          float64
# Gender        object
# Salary         int64
# Join Date     object
# dtype: object

# %%
#Converting a Column to a DateTime Type
df['Join Date'] = pd.to_datetime(df['Join Date'])
print(df.dtypes)
# Out:
# Name                 object
# Age                 float64
# Gender               object
# Salary                int64
# Join Date    datetime64[ns]
# dtype: object

# %% [markdown]
# ## **Removing Duplicates**

# %%
data = {
    "Name": ["Alice", "Bob", "Alice", "David"],
    "Age": [25, 30, 25, 40],
    "City": ["NY", "LA", "NY", "Chicago"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age     City
# 0  Alice   25       NY
# 1    Bob   30       LA
# 2  Alice   25       NY
# 3  David   40  Chicago

# %%
#Discovering duplicates
print(df.duplicated())

#Returns True for every row that is a duplicate, otherwise False
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df.drop_duplicates(inplace = True)
print(df)
# Out:
#     Name  Age     City
# 0  Alice   25       NY
# 1    Bob   30       LA
# 3  David   40  Chicago
