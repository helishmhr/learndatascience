# %%
import numpy as np
import pandas as pd

# %%
x=[10,20,30,40]
y= pd.Series(x)
y
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
data = [
    {'Name': 'John', 'Age': 28, 'City': 'New York', 'Salary': 65000 },
    {'Name': 'Anna', 'Age': 34, 'City': 'Paris', 'Salary': 70000  },
    {'Name': 'Peter', 'Age': 29, 'City': 'Berlin', 'Salary': 62000 },
]
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %%
df['Name']= ['Ram', 'Shyam', 'Hari']

# %%
df
# Out:
#     Name  Age      City  Salary
# 0    Ram   28  New York   65000
# 1  Shyam   34     Paris   70000
# 2   Hari   29    Berlin   62000

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series
