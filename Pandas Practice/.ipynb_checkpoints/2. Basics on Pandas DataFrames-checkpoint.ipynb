# %% [markdown]
# # **Basics on Pandas DataFrames**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Creating DataFrame**

# %%
#creating DataFrame from a list
lst = ['John', 'Anna', 'Peter', 'Linda']
df = pd.DataFrame(lst)
print(df)
# Out:
#        0
# 0   John
# 1   Anna
# 2  Peter
# 3  Linda

# %%
#Creating a DataFrame from a List of Dictionaries  
data = [
    {'Name': 'John', 'Age': 28, 'City': 'New York', 'Salary': 65000 },
    {'Name': 'Anna', 'Age': 34, 'City': 'Paris', 'Salary': 70000  },
    {'Name': 'Peter', 'Age': 29, 'City': 'Berlin', 'Salary': 62000 },
]
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %%
#creating a data frame from dictionary
mydataset = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(mydataset)

print(df)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ## **Accessing Specific Columns**

# %%
#getting a specific column
print(df['Name'])
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
#getting multiple columns
print(df[['Name', 'Age']])
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ## **Accessing Specific Rows**

# %%
#getting a specific row of data frame
print(df.loc[0])
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
#getting multiple rows
print(df.loc[[0, 1]])
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %% [markdown]
# ## **Accessing Specific Rows and Columns**

# %%
#getting rows and columns
print(df.loc[[0,1]][['Name','Age']])
# Out:
#    Name  Age
# 0  John   28
# 1  Anna   34

# %% [markdown]
# ## **Conditional Selections**

# %%
#selecting persons with age>30
print(df[df['Age']>30])
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#selecting persons with age>30 and city=paris
print(df[(df['Age']>30)& (df['City']=='Paris')])
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000

# %% [markdown]
# ## **Named Indexes**

# %%
#Giving own names to indices(naming each row with own name)
df=pd.DataFrame(mydataset, index=['p1', 'p2', 'p3','p4'])
print(df)
# Out:
#      Name  Age      City  Salary
# p1   John   28  New York   65000
# p2   Anna   34     Paris   70000
# p3  Peter   29    Berlin   62000
# p4  Linda   42    London   85000

# %%
#getting a specific row of data frame having named indices
print(df.loc['p1'])
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: p1, dtype: object

# %% [markdown]
# ## **Concatenating DataFrames**

# %%
#Concatenating DataFrames Vertically
df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'C': [7, 8]})

res = pd.concat([df1, df2])
print(res)
# Out:
#    A    B    C
# 0  1  3.0  NaN
# 1  2  4.0  NaN
# 0  5  NaN  7.0
# 1  6  NaN  8.0

# %%
#Concatenating DataFrames Horizontally
res = pd.concat([df1, df2], axis=1)
print(res)
# Out:
#    A  B  A  C
# 0  1  3  5  7
# 1  2  4  6  8

# %% [markdown]
# ## **Merging DataFrames**

# %%
# DataFrame 1: Employee information
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salary information
salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

print(employees)
print()
print(salaries)
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR
#
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
#inner merge
res=pd.merge(employees,salaries, on='employee_id',how='inner')
print(res)
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
#outer merge
res=pd.merge(employees,salaries, on='employee_id',how='outer')
print(res)
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
#left merge
res=pd.merge(employees,salaries, on='employee_id',how='left')
print(res)
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
#right merge
res=pd.merge(employees,salaries, on='employee_id',how='right')
print(res)
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %%
#merging on different column names

# DataFrame 1: Employee information
employees = pd.DataFrame({
    'id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salary information
salaries = pd.DataFrame({
    'emp_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

res=pd.merge(employees,salaries,left_on='id',right_on='emp_id',how='inner')
print(res)
# Out:
#    id   name department  emp_id  salary  bonus
# 0   1   John         HR       1   60000   5000
# 1   2   Anna         IT       2   80000  10000
# 2   3  Peter    Finance       3   65000   7000

# %% [markdown]
# ## **Apply Function**

# %%
mydataset = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(mydataset)

print(df)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#applying a custom or built-in function to each element of a Series or along an axis of a DataFrame
def multiplier(value):
    return value*2

df['Salary']=df['Salary'].apply(multiplier)
print(df)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York  130000
# 1   Anna   34     Paris  140000
# 2  Peter   29    Berlin  124000
# 3  Linda   42    London  170000
