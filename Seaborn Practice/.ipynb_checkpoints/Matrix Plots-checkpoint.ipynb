# %% [markdown]
# # **Matrix Plot**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Heat Map**

# %%
#simple heatmap
# Generating a 10x10 matrix of random numbers
data = np.random.randint(1, 100, (10, 10))
print(data)
sns.heatmap(data)
plt.show()
# Out:
# [[31 97 98  6 87 43 84 36 24 41]
#  [29 10 88 44 77 11  5 39 99 49]
#  [97 92 36 35 73 55 67 21 79 40]
#  [87  7 93 82 61 25 42 68 64 37]
#  [50 60 18  5 99 44 64 73 89 22]
#  [71 67 55 63 30 40 66 89 42 58]
#  [38  6 30 95 69 25 37 27 88 44]
#  [79 94  5 58 70  5  3 28 98 84]
#  [60 32 43 61 81 16 17 76 83 88]
#  [94 92 36  7 28 86 90 12 15 97]]

# %%
#showing cell values
sns.heatmap(data, annot=True)
plt.show()

# %%
#modifying the color scheme of the heatmap
sns.heatmap(data, cmap="Blues")
plt.show()

# %% [markdown]
# ## **Correlation Heat Map**

# %%
#load dataset
tips= sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#selecting only numerical variables
new=tips[["total_bill","tip","size"]]
new
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
#generating correlation matrix
corr_mat=new.corr()
corr_mat
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#plotting correlation heatmap
sns.heatmap(corr_mat, annot=True)
plt.show()
