# %% [markdown]
# # **Pandas Series**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Creating Series**

# %%
#creating series(without label) using lists
x=[10,20,30,40]
y= pd.Series(x)
print(y)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#creating series(with label) using lists
y=pd.Series(x, index=['a','b','c','d'])
print(y)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
#Creating a Series(without label) from a NumPy Array
x = np.array(['g', 'e', 'e', 'k', 's'])

y = pd.Series(x)
print(y)
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
#Creating a Series from a key-value objects(dictionary)
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)

#Note: The keys of the dictionary become the labels.
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ## **Accessing elements of Series**

# %%
#accessing elements of series(without label)
print(y[0])
# Out:
# g

# %%
#accessing elements of series(with label)
print(myvar['day1'])
# Out:
# 420
